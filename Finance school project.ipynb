# %% [markdown]
# DATA CLEANING

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2d4eca87-f51a-4dd8-ac80-cbf881a5b776" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d4eca87-f51a-4dd8-ac80-cbf881a5b776">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel('bdd_fi9.xlsx')

# %%
df
# Out:
#           Date  Open_price_compared_yesterday_airbus  Volume_previous_day  \
# 0   2023-01-02                              1.004835               544003
# 1   2023-01-03                              1.011406               667019
# 2   2023-01-04                              1.012511              1101680
# 3   2023-01-05                              1.000696              1314343
# 4   2023-01-06                              1.005565               938465
# ..         ...                                   ...                  ...
# 250 2023-12-21                              0.978013               948657
# 251 2023-12-22                              1.012555               914681
# 252 2023-12-27                              1.007497               550002
# 253 2023-12-28                              1.000572               489581
# 254 2023-12-29                              0.997283               502781
#
#             Mms  Open_price_compared_yesterday_boeing Events  Results
# ...

# %%
df.set_index('Date', inplace=True)

# %%
plt.boxplot(df['Volume_previous_day'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c23ed0b5b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c23ed0b6050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c23ed0b5840>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c23ed0b6590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c23ed0b6830>],
#  'means': []}

# %%
plt.hist(df['Open_price_compared_yesterday_airbus'])
# Out:
# (array([ 2., 10., 19., 27., 65., 64., 49., 13.,  4.,  2.]),
#  array([0.96029773, 0.96843463, 0.97657152, 0.98470841, 0.99284531,
#         1.0009822 , 1.00911909, 1.01725599, 1.02539288, 1.03352977,
#         1.04166667]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['Open_price_compared_yesterday_airbus'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c23eb049a80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c23eb049fc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c23eb0497e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c23eb04a500>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c23eb04a7a0>],
#  'means': []}

# %%
plt.boxplot(df['Mms'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c23eaec2530>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c23eaec2a70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c23eaec2290>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c23eb04abc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c23eaec2e00>],
#  'means': []}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 255 entries, 2023-01-02 to 2023-12-29
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Open_price_compared_yesterday_airbus  255 non-null    float64
#  1   Volume_previous_day                   255 non-null    int64
#  2   Mms                                   255 non-null    float64
#  3   Open_price_compared_yesterday_boeing  237 non-null    float64
#  4   Events                                255 non-null    object
#  5   Results                               255 non-null    int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 13.9+ KB

# %%
df.isnull().sum()
# Out:
# Open_price_compared_yesterday_airbus     0
# Volume_previous_day                      0
# Mms                                      0
# Open_price_compared_yesterday_boeing    18
# Events                                   0
# Results                                  0
# dtype: int64

# %%
q1_1 = df['Open_price_compared_yesterday_airbus'].quantile(0.25)
q3_1 = df['Open_price_compared_yesterday_airbus'].quantile(0.75)
IQR_1 = (q3_1-q1_1)
lower_bound_1=q1_1-(IQR_1*1.5)
higher_bound_1=q3_1+(IQR_1*1.5)
df.Open_price_compared_yesterday_airbus[(df.Open_price_compared_yesterday_airbus<lower_bound_1)|(df.Open_price_compared_yesterday_airbus>higher_bound_1)]=np.nan
df.Open_price_compared_yesterday_airbus.fillna(df['Open_price_compared_yesterday_airbus'].mean(), inplace=True)
# Out:
# <ipython-input-12-e56fadcba6f8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Open_price_compared_yesterday_airbus[(df.Open_price_compared_yesterday_airbus<lower_bound_1)|(df.Open_price_compared_yesterday_airbus>higher_bound_1)]=np.nan

# %%
q1_2 = df['Volume_previous_day'].quantile(0.25)
q3_2 = df['Volume_previous_day'].quantile(0.75)
IQR_2 = (q3_2-q1_2)
lower_bound_2=q1_2-(IQR_2*1.5)
higher_bound_2=q3_2+(IQR_2*1.5)
df.Volume_previous_day[(df.Volume_previous_day<lower_bound_2)|(df.Volume_previous_day>higher_bound_2)]=np.nan
df.Volume_previous_day.fillna(df['Volume_previous_day'].mean(), inplace=True)
# Out:
# <ipython-input-13-2bbe3e7223b6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Volume_previous_day[(df.Volume_previous_day<lower_bound_2)|(df.Volume_previous_day>higher_bound_2)]=np.nan

# %%
q1_3 = df['Mms'].quantile(0.25)
q3_3 = df['Mms'].quantile(0.75)
IQR_3 = (q3_3-q1_3)
lower_bound_3=q1_3-(IQR_3*1.5)
higher_bound_3=q3_3+(IQR_3*1.5)
df.Mms[(df.Mms<lower_bound_3)|(df.Mms>higher_bound_3)]=np.nan
df.Mms.fillna(df['Mms'].mean(), inplace=True)
# Out:
# <ipython-input-14-e6f19e425f66>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Mms[(df.Mms<lower_bound_3)|(df.Mms>higher_bound_3)]=np.nan

# %%
q1_4 = df['Open_price_compared_yesterday_boeing'].quantile(0.25)
q3_4 = df['Open_price_compared_yesterday_boeing'].quantile(0.75)
IQR_4 = (q3_4-q1_4)
lower_bound_4=q1_4-(IQR_4*1.5)
higher_bound_4=q3_4+(IQR_4*1.5)
df.Open_price_compared_yesterday_boeing[(df.Open_price_compared_yesterday_boeing<lower_bound_4)|(df.Open_price_compared_yesterday_boeing>higher_bound_4)]=np.nan
df.Open_price_compared_yesterday_boeing.fillna(df['Open_price_compared_yesterday_boeing'].mean(), inplace=True)
# Out:
# <ipython-input-15-aafaf5063725>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Open_price_compared_yesterday_boeing[(df.Open_price_compared_yesterday_boeing<lower_bound_4)|(df.Open_price_compared_yesterday_boeing>higher_bound_4)]=np.nan

# %%
df.isnull().sum()
# Out:
# Open_price_compared_yesterday_airbus    0
# Volume_previous_day                     0
# Mms                                     0
# Open_price_compared_yesterday_boeing    0
# Events                                  0
# Results                                 0
# dtype: int64

# %% [markdown]
# TRANSFORMATION IN DUMMIES OF THE EVENT CATEGORY

# %%
pd.get_dummies(df['Events'] , dtype= float)
# Out:
#              No  Yes
# Date
# 2023-01-02  1.0  0.0
# 2023-01-03  0.0  1.0
# 2023-01-04  1.0  0.0
# 2023-01-05  1.0  0.0
# 2023-01-06  1.0  0.0
# ...         ...  ...
# 2023-12-21  1.0  0.0
# 2023-12-22  1.0  0.0
# 2023-12-27  0.0  1.0
# 2023-12-28  1.0  0.0
# 2023-12-29  1.0  0.0
#
# [255 rows x 2 columns]

# %%
ev=pd.get_dummies(df['Events'],dtype= float, drop_first=True)
df2=pd.concat([df,ev], axis =1)
df2.head()
# Out:
#             Open_price_compared_yesterday_airbus  Volume_previous_day  \
# Date
# 2023-01-02                              1.004835             544003.0
# 2023-01-03                              1.011406             667019.0
# 2023-01-04                              1.012511            1101680.0
# 2023-01-05                              1.000696            1314343.0
# 2023-01-06                              1.005565             938465.0
#
#                    Mms  Open_price_compared_yesterday_boeing Events  Results  \
# Date
# 2023-01-02  109.833411                              1.002090     No        1
# 2023-01-03  109.975389                              1.002090    Yes        0
# 2023-01-04  110.183428                              1.002090     No        0
# 2023-01-05  110.407242                              1.006629     No        0
# 2023-01-06  110.742469                              1.039075     No        0
#
#             Yes
# Date
# 2023-01-02  0.0
# 2023-01-03  1.0
# ...

# %%
df2.drop('Events', axis =1, inplace = True)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 255 entries, 2023-01-02 to 2023-12-29
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Open_price_compared_yesterday_airbus  255 non-null    float64
#  1   Volume_previous_day                   255 non-null    float64
#  2   Mms                                   255 non-null    float64
#  3   Open_price_compared_yesterday_boeing  255 non-null    float64
#  4   Results                               255 non-null    int64
#  5   Yes                                   255 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 13.9 KB

# %%
df2
# Out:
#             Open_price_compared_yesterday_airbus  Volume_previous_day  \
# Date
# 2023-01-02                              1.004835             544003.0
# 2023-01-03                              1.011406             667019.0
# 2023-01-04                              1.012511            1101680.0
# 2023-01-05                              1.000696            1314343.0
# 2023-01-06                              1.005565             938465.0
# ...                                          ...                  ...
# 2023-12-21                              0.978013             948657.0
# 2023-12-22                              1.012555             914681.0
# 2023-12-27                              1.007497             550002.0
# 2023-12-28                              1.000572             489581.0
# 2023-12-29                              0.997283             502781.0
#
#                    Mms  Open_price_compared_yesterday_boeing  Results  Yes
# Date
# ...

# %%
df2['Open_price_compared_yesterday_airbus'].describe()
# Out:
# count    255.000000
# mean       1.001215
# std        0.012156
# min        0.969637
# 25%        0.993531
# 50%        1.001308
# 75%        1.009431
# max        1.033592
# Name: Open_price_compared_yesterday_airbus, dtype: float64

# %%
df2['Volume_previous_day'].describe()
# Out:
# count    2.550000e+02
# mean     9.299551e+05
# std      2.833089e+05
# min      3.562660e+05
# 25%      7.323905e+05
# 50%      8.941490e+05
# 75%      1.102591e+06
# max      1.727332e+06
# Name: Volume_previous_day, dtype: float64

# %%
df2['Mms'].describe()
# Out:
# count    255.000000
# mean     125.334433
# std        6.867050
# min      109.833411
# 25%      120.099761
# 50%      125.721000
# 75%      130.889000
# max      139.138001
# Name: Mms, dtype: float64

# %%
df2['Open_price_compared_yesterday_boeing'].describe()
# Out:
# count    255.000000
# mean       1.002090
# std        0.013462
# min        0.966597
# 25%        0.994051
# 50%        1.002090
# 75%        1.009217
# max        1.040122
# Name: Open_price_compared_yesterday_boeing, dtype: float64

# %%
df2['Yes'].value_counts()
# Out:
# Yes
# 0.0    227
# 1.0     28
# Name: count, dtype: int64

# %%
df2['Results'].value_counts()
# Out:
# Results
# 0    145
# 1    110
# Name: count, dtype: int64

# %% [markdown]
# DATABASE SPLIT

# %%
df['Results'] = df['Results'].astype('category')

# %%
from sklearn.model_selection import train_test_split
x = df2.drop("Results", axis = 1).drop("Yes", axis =1)
y = df2["Results"]
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state =2)

# %% [markdown]
# KNN

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit (x_train)
# Out:
# StandardScaler()

# %%
stand_x_train = scaler.transform(x_train)
df_stand_x_train = pd.DataFrame(stand_x_train, columns = x_train.columns)
df_stand_x_train
# Out:
#      Open_price_compared_yesterday_airbus  Volume_previous_day       Mms  \
# 0                                0.892802            -1.395601  0.678243
# 1                               -1.824382            -0.336914 -0.154410
# 2                                0.860791            -0.704612  0.739580
# 3                                0.347789            -0.234876 -0.150890
# 4                                0.340166            -0.810612  0.620312
# ..                                    ...                  ...       ...
# 173                              1.315073             1.651555 -1.543515
# 174                             -0.219529            -0.204964 -0.859425
# 175                              0.353117             0.436243  0.984487
# 176                              0.992892             0.962749 -1.838887
# 177                              0.806839            -0.950454  0.634388
#
#      Open_price_compared_yesterday_boeing
# 0                                1.702781
# ...

# %%
stand_x_test = scaler.transform(x_test)
df_stand_x_test = pd.DataFrame(stand_x_test, columns = x_test.columns)
df_stand_x_test
# Out:
#     Open_price_compared_yesterday_airbus  Volume_previous_day       Mms  \
# 0                               0.000843             2.908324 -0.693771
# 1                               1.026634             1.464661 -1.917039
# 2                              -1.967206             2.601848  1.040047
# 3                               1.707909             0.746589 -0.214020
# 4                              -1.540552            -1.218104  0.952485
# ..                                   ...                  ...       ...
# 72                              0.794191            -0.811345  0.120573
# 73                             -2.174493            -0.535115  0.505045
# 74                             -0.393424            -1.301124  0.031678
# 75                             -0.376851            -2.070902  0.737506
# 76                              0.358861            -1.276780  0.709356
#
#     Open_price_compared_yesterday_boeing
# 0                               1.671780
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(df_stand_x_train,y_train)
y_pred = knn.predict(df_stand_x_test)

# %%
error_rate =[]

for i in range (1,40):
  knn = KNeighborsClassifier(n_neighbors=i)
  knn.fit(df_stand_x_train,y_train)
  y_pred=knn.predict(df_stand_x_test)
  error_rate.append(np.mean(y_pred !=y_test))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)

plt.title('Error Rate vs. K Value')

plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# OPTIMAL MODEL WITH KNN

# %%
knn=KNeighborsClassifier(n_neighbors=31)
knn.fit(df_stand_x_train, y_train)
y_pred = knn.predict(df_stand_x_test)

print ('with KNN = 31')
print (confusion_matrix(y_test, y_pred))
print (classification_report (y_test, y_pred))
# Out:
# with KNN = 31
# [[33 13]
#  [ 8 23]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        46
#            1       0.64      0.74      0.69        31
#
#     accuracy                           0.73        77
#    macro avg       0.72      0.73      0.72        77
# weighted avg       0.74      0.73      0.73        77

# %% [markdown]
# WITH DECISION TREE

# %%
from sklearn.model_selection import train_test_split
x2 = df2.drop("Results", axis = 1)
y2 = df2["Results"]
x2_train, x2_test, y2_train, y2_test = train_test_split(x2,y2,test_size=0.3, random_state =2)

# %%
from sklearn.tree import DecisionTreeClassifier
dtree= DecisionTreeClassifier(max_depth=3)
dtree.fit(x2_train,y2_train)
y_pred_2= dtree.predict(x2_test)

# %%
print ('with decision tree')
print(confusion_matrix(y2_test,y_pred_2))
print(classification_report(y2_test, y_pred_2))
# Out:
# with decision tree
# [[36 10]
#  [ 9 22]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        46
#            1       0.69      0.71      0.70        31
#
#     accuracy                           0.75        77
#    macro avg       0.74      0.75      0.74        77
# weighted avg       0.75      0.75      0.75        77

# %%
y.unique()
# Out:
# array([1, 0])

# %%
from sklearn import tree
plt.figure(figsize=(20,15))
tree.plot_tree(dtree,
               feature_names = x.columns,
               class_names=['1','0'],
               rounded=True,
               filled = True);

# %% [markdown]
# WITH RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100)
rf.fit (x2_train,y2_train)
y_pred_3 = rf.predict(x2_test)

# %%
print ('with random forest')
print(confusion_matrix(y2_test,y_pred_3))
print(classification_report(y2_test, y_pred_3))
# Out:
# with random forest
# [[33 13]
#  [12 19]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73        46
#            1       0.59      0.61      0.60        31
#
#     accuracy                           0.68        77
#    macro avg       0.66      0.67      0.66        77
# weighted avg       0.68      0.68      0.68        77

# %% [markdown]
# LETS NOW DO THE NEURAL NETWORKS

# %%
x3 = df2.drop('Results', axis=1).to_numpy()
y3 = df2['Results'].to_numpy()

# %%
x3_train,x3_test,y3_train,y3_test= train_test_split (x3,y3, test_size=0.3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.optimizers import Adam

# %%
model= Sequential()
model.add(Dense(units=5, activation='relu'))
model.add(Dense(units=3, activation ='relu'))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose = 1, patience =25)

# %%
model.fit (x = x3_train,
           y = y3_train,
           epochs=500,
           validation_data = (x3_test,y3_test),
           callbacks = [early_stop])
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 27ms/step - loss: 119166.0547 - val_loss: 143341.8594
# Epoch 2/500
# 6/6 [==============================] - 0s 6ms/step - loss: 113630.8516 - val_loss: 137017.6562
# Epoch 3/500
# 6/6 [==============================] - 0s 8ms/step - loss: 108842.3906 - val_loss: 130616.1172
# Epoch 4/500
# 6/6 [==============================] - 0s 9ms/step - loss: 103861.7500 - val_loss: 124415.6484
# Epoch 5/500
# 6/6 [==============================] - 0s 6ms/step - loss: 98810.3828 - val_loss: 118459.1406
# Epoch 6/500
# 6/6 [==============================] - 0s 10ms/step - loss: 93851.3359 - val_loss: 112703.2734
# Epoch 7/500
# 6/6 [==============================] - 0s 9ms/step - loss: 89246.6875 - val_loss: 107037.9453
# Epoch 8/500
# 6/6 [==============================] - 0s 5ms/step - loss: 84745.3516 - val_loss: 101455.7656
# Epoch 9/500
# 6/6 [==============================] - 0s 9ms/step - loss: 80214.4922 - val_loss: 96061.3125
# ...

# %%
model_loss=pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <Axes: >

# %%
y3_pred = (model.predict(x3_test)>=0.5).astype(int)
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
print (confusion_matrix(y_test,y_pred))
print (classification_report(y_test,y_pred))
# Out:
# [[33 13]
#  [ 8 23]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        46
#            1       0.64      0.74      0.69        31
#
#     accuracy                           0.73        77
#    macro avg       0.72      0.73      0.72        77
# weighted avg       0.74      0.73      0.73        77
